# %% [raw]
# ---
# description: A simple health check function to verify that the application is running
#   correctly.
# order: 1
# output-file: 0-health.html
# title: Health Checks
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(health_check)
# Out:
# ---
#
# ### health_check
#
# >      health_check ()
#
# *Check the health of the application.*

# %%
health_check()
# Out:
# The application is healthy!

# %%
#| echo: false
#| output: asis
show_doc(version)
# Out:
# ---
#
# ### version
#
# >      version ()
#
# *Print the version of the application.*

# %%
version()
# Out:
# fast_snippets version: 0.1.1
